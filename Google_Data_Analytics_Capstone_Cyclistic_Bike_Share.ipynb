# %% [markdown]
# <a href="https://colab.research.google.com/github/hilmialfar/Google-Data-Analytics/blob/main/Google_Data_Analytics_Capstone_Cyclistic_Bike_Share.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<h1 align=center>**CYCLISTIC BIKE-SHARE**
#
# #<h2 align=center>**Capstone Project**
# #<h3 align=center>**Google Data Analytics Professional Certificate**

# %% [markdown]
# # **Introduction**

# %% [markdown]
# > It's the **capstone project of Google Data Analytics Professional Certificate** course through **Kominfo Fresh Graduate Digital Talent Scholarship** program. This capstone project involves me as a **Data Analyst working in the marketing analytics team at the Cyclistic Bike Share company**. I will use **PostgreSQL** for database creation and joins between tables, as well as **Python programming language** for cleaning, analyzing, and visualizing data because of its ease of analyzing large datasets.
#
# > The capstone project will be conducted with a **six-stage Data Analysis** process: **Ask, Prepare, Process, Analyze, Share, and Act**. Each stage includes steps that will result in a structure that facilitates decision-making and problem-solving.

# %% [markdown]
# ## About Company
#
# ![image.png](data:image/png;base64,...)
#
#
# > Cyclistic is a bicycle-share company based in Chicago, USA where in 2016, they launched a program offering **short-term rentals throughout the city of Chicago**. Since then, the program has grown to a fleet of 5,824 bicycles that are geotracked and locked into a network of 692 stations across Chicago. The bikes can be **unlocked from one station** and **returned to any other station** in the system **anytime**.
#
# > Cyclistic has set itself apart from its competitors by offering reclining bikes, cargo bikes, and hand tricycles, thus catering to people with disabilities and riders who cannot use a standard two-wheeled motorcycle. The majority of riders opt for traditional bikes, with only 8% of riders using assistive options. **Cyclistic users are more likely to ride for leisure, but about 30% use them to commute to work each day**.
#
# > Cyclistic has flexible pricing plans: single-ride passes, full-day passes, and annual memberships. **Customers who purchase single-ride or full-day passes are referred to as casual riders**. **Customers who purchase annual memberships are Cyclistic members**.

# %% [markdown]
# ## Scenario
# > **Cyclistic’s financial analysts** have concluded that **annual members are much more profitable than casual riders**. Although the pricing flexibility helps Cyclistic attract more customers than usual, **Lily Moreno, the marketing director**, believes that **expanding the number of annual members will be critical to future growth**. Rather than creating a marketing campaign targeting all-new customers, Moreno believes there is a **very good chance to convert casual riders into members**. She notes that casual riders already know the Cyclistic program and have chosen Cyclistic for their mobility needs. **Lily Moreno wants the marketing analysis team to design a new marketing strategy to convert casual riders into annual members**. Obviously, the marketing program recommendations from the marketing analytics team **must be approved by the Cyclistic executive team**, so the recommendations must be supported with insights and visualizations that are easily understood.

# %% [markdown]
# # **Ask**

# %% [markdown]
# > Data analysts are required **to define problems and objectives of the business by asking questions** at this stage.

# %% [markdown]
# ## **Defining the Problem**

# %% [markdown]
# > **Lily Moreno wants the marketing analysis team to design a new effective marketing strategy to convert casual riders into annual members** based on **three questions** that can guide future marketing programs.
#
# 1. **How do annual members (Cyclistic members) and casual riders use Cyclistic bikes differently?**
# 2. Why would casual riders buy Cyclistic annual memberships?
# 3. How can Cyclistic use digital media to influence casual riders to become members?
#
# > **Lily Moreno, the director of marketing and my manager** has assigned for me **to answer the first question**.

# %% [markdown]
# ## **Business Objectives**

# %% [markdown]
# > **Design a new marketing strategies to convert casual riders into annual members based on data-driven insights.**

# %% [markdown]
# ## **Business Task**

# %% [markdown]
# > **Analyzed a dataset of historical bike trips over the past 12 months (October 2021 - September 2022)** to identify **how annual members and casual riders use Cyclistic bikes differently**.

# %% [markdown]
# ## **Stakeholders**

# %% [markdown]
# > 1. **Primary**
# *   **Lily Moreno as marketing director** is responsible for marketing Cyclistic to promote the bike-sharing program.
# *   **Cyclistic's executive team** will decide whether to approve the recommended strategy from the marketing team.
#
#
# > 2. **Secondary**
# *   **Cyclistic's marketing analytics team** is responsible for collecting, analyzing and reporting data that helps guide Cyclistic's marketing strategy.

# %% [markdown]
# ## **Deliverables**

# %% [markdown]
# > * A description of all data sources used
# * Documentation of any cleaning or manipulation of data
# * A summary of the analysis
# * Supporting visualizations and key findings
# * Top three to four recommendations based on the analysis

# %% [markdown]
# ## **Timeline**

# %% [markdown]
# * Start date: 4 November 2022
# * End date: 6 November 2022

# %% [markdown]
# # **Prepare**

# %% [markdown]
# > At this stage, the data analyst **determines what data is needed, how to get the data, collect and store the data, ensure the data is credible and unbiased, and know the limitations of the data**.

# %% [markdown]
# ## **Description of Data**

# %% [markdown]
# > The dataset used is public data obtained from **Motivate International Inc. under this [license](https://ride.divvybikes.com/data-license-agreement) and can be found [here](https://divvy-tripdata.s3.amazonaws.com/index.html).** This dataset has a different name because **Cyclistic is a fictional company**. The dataset used is **structured data composed of rows (records) and columns (fields) with CSV (comma-separated values) file format**. Each record represents one ride, and each ride has a unique field that identifies it (`ride_id`). **Each record is also anonymized data that does not contain personally identifiable information such as the name, phone number, residential address, or email address of the Cylistic user**. Each CSV file contains a dataset of historical bike trips by Cylistic users for one month, while this project requires datasets for the **last 12 months (prior to this project), from October 2021 to September 2022**. Thus, there are **12 CSV files** that will be used and have been stored in the **database in PostgreSQL**.

# %% [markdown]
# > Each Cyclistic user trip historical dataset file contains **13 variables** and the description of each variable is below:
#
# | Field/Column | Description |
# | ------------ | ----------- |
# | ride_id | Unique ID assigned with each ride |
# | rideable_type | Type of bicycle used on each ride — classic, docked, or electric |
# | started_at | Date and time at the start of each bike ride |
# | ended_at | Date and time at the end of each bike ride |
# | start_station_name | Station name where each bike ride starts |
# | start_station_id | Station ID where each bike ride starts |
# | end_station_name| Station name where each bike ride ends |
# | end_station_id | Station ID where each bike ride ends |
# | start_lat | Latitude of each starting station |
# | start_lng | Longitude of each starting station |
# | end_lat | Latitude of each ending station |
# | end_lng | Longitude of each ending station |
# | member_casual | Type of membership of each rider |

# %% [markdown]
# ## **Credibility of Data**

# %% [markdown]
# > The **credibility** of the data sources can be determined using the **ROCCC system**.
#
# *   **Reliable**
#
#   This data is public data that contains accurate, and unbiased information, because based on actual transactions collected from each trip of Cyclistic bike-share users, so it is not affected by personal opinions or assumptions.
#
# *   **Original**
#
#   This data is original because it collected from an official source that is copyrighted and legally owns the data so that it can be validated.
#
# *   **Comprehensive**
#
#   This data contains important information that is necessary and relevant to answer the questions in this project, such as the type of Cyclistic users, bike travel time, and type of bike used during the period October 2021 to September 2022.
#
# *   **Current**
#
#   This data is current as it is updated monthly to show the latest information on Cyclistic user trips and covers bike trips during October 2021 to September 2022.
#
# *   **Cited**
#
#   This data can be cited as it was public data sourced from the official website where it was provided by Cyclistic Bike-Share and the city of Chicago.

# %% [markdown]
# ## **Limitations of Data**

# %% [markdown]
# > The rider's personally identifiable information cannot be used because of **data-privacy issues**. Therefore, we were unable to identify where the rider lived in the Cyclistic service area or determine if the rider had purchased multiple single passes.
#
# > Information about each Cyclistic bike **riding ticket fare is also not available**. If the personally identifiable information and ticket fares were available, we could calculate how much money casual riders and Cyclistic members spend. This is to find out which riders spend more money.
#
# > This data also does **not contain data about the use of reclining bikes, hand tricycles and cargo bikes**, where it is said that about 8% of the total riders use the assistance option.
#
# > In addition, this data **only** contains Cyclistic users' trip information during **October 2021 to September 2022**.

# %% [markdown]
# # **Process**

# %% [markdown]
# > Before analyzing data, data analyst should ensure that **the data used is clean and relevant to the problem to be solved** in order to avoid bad insights during data analysis.

# %% [markdown]
# ## **Data Merging**

# %% [markdown]
# > On this project, **multiple datasets will be merged into 1 dataset because 1 CSV dataset file only records bike trips for one month**. Whereas for analysis, it requires a **historical dataset of bike trips for the last 12 months or from October 2021 to September 2022**. Therefore, dataset merging is necessary.
#
# > **Multiple datasets with CSV file format will be merged with the `Union All` function using PostgresSQL** where previously the datasets have been stored in a database. **The datasets to be merged have the same number of fields (columns) and field names (columns).**
#
# > Note: The `Union All` function in SQL is used to join two or more tables into one table vertically, by placing records (rows) from the first table followed by records (rows) from the second table and so on. The `Union All` function only joins data from tables that have the same number of fields (columns) and does not remove duplicate data.

# %% [markdown]
# > Below is the `Union All` query statement to join 12 tables:
#
# ```
# CREATE TABLE trips_all AS
# (
# SELECT * FROM trips_102021
# UNION ALL
# SELECT * FROM trips_112021
# UNION ALL
# SELECT * FROM trips_122021
# UNION ALL
# SELECT * FROM trips_012022
# UNION ALL
# SELECT * FROM trips_022022
# UNION ALL
# SELECT * FROM trips_032022
# UNION ALL
# SELECT * FROM trips_042022
# UNION ALL
# SELECT * FROM trips_052022
# UNION ALL
# SELECT * FROM trips_062022
# UNION ALL
# SELECT * FROM trips_072022
# UNION ALL
# SELECT * FROM trips_082022
# UNION ALL
# SELECT * FROM trips_092022
# );
# ```

# %% [markdown]
# > Furthermore, the combined dataset will be cleaned and analyzed using **Google Colab with the Python programming language** because of its ease in cleaned and analyzed large data rapidly.

# %% [markdown]
# ## **Import Library & Dataset**

# %% [markdown]
# > Imported necessary **Python libraries** such as **Pandas, NumPy, Seaborn, Matplotlib, and Plotly** into our notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pandas.api.types import CategoricalDtype
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# > After importing our library, we will **import the CSV dataset file** into the notebook from the **Google Drive storage** using the `read_csv()` function of the Pandas library.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_trips = pd.read_csv("/content/drive/MyDrive/Digitalent x Google/divvy_trips/divvy_tripdata.csv", encoding='utf-8')

# %%
df_trips
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        620BC6107255BF4C  electric_bike  2021-10-22 12:46:42
# 1        4471C70731AB2E45  electric_bike  2021-10-21 09:12:37
# 2        26CA69D43D15EE14  electric_bike  2021-10-16 16:28:39
# 3        362947F0437E1514  electric_bike  2021-10-16 16:17:48
# 4        BB731DE2F2EC51C5  electric_bike  2021-10-20 23:17:54
# ...                   ...            ...                  ...
# 5828230  32ECA2B32C4B6F85   classic_bike  2022-09-05 17:59:21
# 5828231  14801F713026AEAE   classic_bike  2022-09-30 17:20:54
# 5828232  7CCAF5D6E88E45C0  electric_bike  2022-09-04 11:39:37
# 5828233  AF9A129D9AFAA40B  electric_bike  2022-09-28 13:42:45
# 5828234  60B56F4897429FCE  electric_bike  2022-09-01 20:07:04
#
#                     ended_at        start_station_name start_station_id  \
# 0        2021-10-22 12:49:50  Kingsbury St & Kinzie St     KA1503000043
# 1        2021-10-21 09:14:14                       NaN              NaN
# ...

# %% [markdown]
# > This dataset contains **13 columns and 5,828,235 rows** which indicates that the data is large size. Let us look at the data types of each column using the `info()` function from the Pandas library.

# %%
df_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5828235 entries, 0 to 5828234
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lot           float64
#  10  end_lat             float64
#  11  end_lot             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 578.1+ MB

# %% [markdown]
# > The data type of the `started_at` and `ended_at` columns should be `datetime64` because they **contain date and time values**.

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# > The data cleaning process involves identifying errors in the dataset and then correcting or removing them. Data errors can be in the form of **duplicate data, incomplete (missing value), inconsistent or irrelevant to the problem we want to solve or our business objectives**, which will lead to **bad insights**. **Bad insights** are dangerous in marketing because they can lead **to poorly targeted campaign decisions**.

# %% [markdown]
# > First, **columns** that are **not relevant** for analysis **will be removed**. In the analysis process, the columns `end_station_name`, `end_station_id`, `end_lat`, and `end_lot` will not be used. Because what is needed is to know from which **station the casual rider starts the trip to target the location of the marketing campaign**.

# %%
df_trips = df_trips.drop(columns=['end_station_name', 'end_station_id', 'end_lat', 'end_lot'])
df_trips.head(4)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  620BC6107255BF4C  electric_bike  2021-10-22 12:46:42  2021-10-22 12:49:50
# 1  4471C70731AB2E45  electric_bike  2021-10-21 09:12:37  2021-10-21 09:14:14
# 2  26CA69D43D15EE14  electric_bike  2021-10-16 16:28:39  2021-10-16 16:36:26
# 3  362947F0437E1514  electric_bike  2021-10-16 16:17:48  2021-10-16 16:19:03
#
#          start_station_name start_station_id  start_lat  start_lot  \
# 0  Kingsbury St & Kinzie St     KA1503000043  41.889186 -87.638495
# 1                       NaN              NaN  41.930000 -87.700000
# 2                       NaN              NaN  41.920000 -87.700000
# 3                       NaN              NaN  41.920000 -87.690000
#
#   member_casual
# 0        member
# 1        member
# 2        member
# 3        member

# %% [markdown]
# > Next is to check the total number of **missing values** in the dataset.

# %%
na_df = df_trips.isnull().sum()
na_df = pd.DataFrame(na_df, columns=['Missing Value']).reset_index(drop=False).rename(columns={"index": "Variabel"})
na_df['Percentage of Missing Values'] = ((na_df['Missing Value']/len(df_trips))*100).round(2)
na_df.sort_values(by=['Missing Value'], ascending=False).reset_index(drop=True)
# Out:
#              Variabel  Missing Value  Percentage of Missing Values
# 0  start_station_name         895032                         15.36
# 1    start_station_id         895032                         15.36
# 2             ride_id              0                          0.00
# 3       rideable_type              0                          0.00
# 4          started_at              0                          0.00
# 5            ended_at              0                          0.00
# 6           start_lat              0                          0.00
# 7           start_lot              0                          0.00
# 8       member_casual              0                          0.00

# %% [markdown]
# > `The start_station_name` and `start_station_id` columns each have **895032 missing values or 15.36% of the total rows**. This needs to be discussed with the director and marketing analytics team as the stations where Cyclistic's casual riders pick up their bikes can be **recommended locations for marketing campaigns**. For now, both columns will **still be used as secondary recommendations** in the aspect of marketing campaign location.

# %% [markdown]
# > It then checks if there are **duplicate values** in the dataset and if so, how many there are using the function `.duplicated().sum()`. Because the presence of duplicate data will result in **bad insights**.

# %%
df_trips.duplicated().sum()
print(f'Number of duplicate data : {df_trips.duplicated().sum()}')
# Out:
# Number of duplicate data : 0

# %% [markdown]
# > There are **no duplicate values**

# %% [markdown]
# > Furthermore, the `started_at` and `ended_at` columns should be converted to `datetime64` with the function `astype()`. In addition, rename the `member_casual` column to `user_type` with the function `rename()` and convert the data types for the `rideable_type` and `user_type` columns.

# %%
df_trips[['started_at', 'ended_at']] = df_trips[['started_at', 'ended_at']].astype('datetime64[ns]')
df_trips = df_trips.rename({'member_casual': 'user_type'}, axis='columns')
df_trips = df_trips.astype({'rideable_type':'category', 'user_type':'category'})
df_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5828235 entries, 0 to 5828234
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       category
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   start_lat           float64
#  7   start_lot           float64
#  8   user_type           category
# dtypes: category(2), datetime64[ns](2), float64(2), object(3)
# memory usage: 322.4+ MB

# %% [markdown]
# > The data has been cleaned and then proceeds to the data manipulation stage.

# %% [markdown]
# ## **Data Manipulation**

# %% [markdown]
# > Data manipulation is the process of changing or altering data to make it more **understandable and organized**. The data manipulation that will be conducted is **extracting or adding data and filtering information based on the analysis requirements**.
#
# > From this dataset with 13 columns/variables, we need new columns that show information about the **length of each trip, which days of the week the rider frequently trips, and what time the rider starts the trip**. These metrics will be an **important insight** to answer the question **"How do annual members and casual riders use Cyclistic bikes differently?"**.

# %% [markdown]
# > **Creating a new variable**, **`ride_duration`**, which shows the **duration** of the user's trip in **minutes** using the `.insert()` function, by calculating the **time difference between the `ended_at` and `started_at` variables**. Then sort the values of the `ride_duration` variable in **ascending order** to see what the **lowest value** is or identify any errors such as **negative values**.

# %%
df_trips.insert(loc=4, column="ride_duration", value= df_trips['ended_at'] - df_trips['started_at'])
df_trips['ride_duration'] = df_trips['ride_duration'] / pd.Timedelta(minutes=1)
df_trips.sort_values(by = 'ride_duration')
# Out:
#                   ride_id  rideable_type          started_at  \
# 5544691  E137518FFE807752  electric_bike 2022-09-28 11:04:32
# 3333944  38B9F148CE80499B  electric_bike 2022-06-07 19:23:03
# 2874456  B897BE02B21FA75E  electric_bike 2022-06-07 19:15:39
# 3049556  BF114472ABA0289C  electric_bike 2022-06-07 19:14:47
# 2874879  072E947E156D142D  electric_bike 2022-06-07 19:14:46
# ...                   ...            ...                 ...
# 1525648  23697816035F9A8F    docked_bike 2022-03-05 19:08:58
# 804824   C8DD5E89BE2DAD7B    docked_bike 2021-11-06 16:53:11
# 3358358  94DD1FB2367EA8B6    docked_bike 2022-06-15 07:56:59
# 2703463  DCFE0DB8022DFABC    docked_bike 2022-05-08 00:28:53
# 360556   A310C7270FD730B6    docked_bike 2021-10-02 18:35:36
#
#                    ended_at  ride_duration                start_station_name  \
# 5544691 2022-09-21 06:31:11  -10353.350000             Cornell Dr & Hayes Dr
# ...

# %% [markdown]
# > It can be seen that many rows contain **negative values**. The error occurs because the "end time" is earlier than the "start time" in each row. In addition, there is an **extreme value** in the `ride_duration` variable, which is **40705 minutes** or **22 days** with the user type being **casual riders**. This is unusual considering that **casual riders are customers who purchase single-ride or full-day tickets**, which means that the maximum **use of the bike is one day** and the program of the Cyclistic company is **short-term rentals throughout the city of Chicago**. Perhaps these values are **outliers**, so we need to check for **outliers** using **boxplots**.

# %%
sns.boxplot(data = df_trips, x ='user_type', y = 'ride_duration', order = ['member', 'casual'])
plt.show()

# %% [markdown]
# > **Outliers** in the `ride_duration` variable for **casual riders** are **numerous**. Since there is **no information** on the **limit** of **maximum duration** of **bike usage** in **Cyclistic program**, the **median** value will be used instead of the **mean** value to determine the difference between **casual riders** and **annual members** based on **trip duration**. That's because the **mean** value is strongly **influenced** by **outliers** while the **median** value is **not**, so the **median** value will be more **accurate** for our **analysis**.

# %% [markdown]
# > Of course, the `ride_duration` variable will be **filtered**. **Values below 1 minute including negative values will not be used** because it is **impossible** for the **ride duration** to be **0 minutes to negative**.

# %%
df_trips = df_trips[df_trips['ride_duration'] >= 1]
df_trips = df_trips.reset_index(drop=True)

df_trips.head(4)
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  620BC6107255BF4C  electric_bike 2021-10-22 12:46:42 2021-10-22 12:49:50
# 1  4471C70731AB2E45  electric_bike 2021-10-21 09:12:37 2021-10-21 09:14:14
# 2  26CA69D43D15EE14  electric_bike 2021-10-16 16:28:39 2021-10-16 16:36:26
# 3  362947F0437E1514  electric_bike 2021-10-16 16:17:48 2021-10-16 16:19:03
#
#    ride_duration        start_station_name start_station_id  start_lat  \
# 0       3.133333  Kingsbury St & Kinzie St     KA1503000043  41.889186
# 1       1.616667                       NaN              NaN  41.930000
# 2       7.783333                       NaN              NaN  41.920000
# 3       1.250000                       NaN              NaN  41.920000
#
#    start_lot user_type
# 0 -87.638495    member
# 1 -87.700000    member
# 2 -87.700000    member
# 3 -87.690000    member

# %% [markdown]
# > The new columns `ride_hour`, `ride_day`, `ride_month`, `ride_year`, and `ride_season` are added by extracting the value of `started_at`. These columns are created to make the data **more understandable** and as **a metric to find out the times when riders often start their rides**.

# %% [markdown]
# > **Season information** in the City of **Chicago** for **October 2021 to September 2022** was obtained from [**Weather Spark**](https://id.weatherspark.com/h/y/14091/2021/Cuaca-Historis-selama-2021-di-Chicago-Illinois-Amerika-Serikat) and here are the details:
# * **Summer**: June, July, and August.
# * **Winter**: December, January, and February.
# * **Spring**: March, April, and May.
# * **Autumn**: September, October, and November.

# %%
df_trips.insert(loc=5, column="ride_hour", value= df_trips['started_at'].dt.hour)

day = [ "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
df_trips.insert(loc=6, column="ride_day", value= df_trips['started_at'].dt.day_name())
df_trips['ride_day'] = df_trips['ride_day'].astype(CategoricalDtype(categories=day, ordered=False))

month = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df_trips.insert(loc=7, column="ride_month", value= df_trips['started_at'].dt.month_name())
df_trips['ride_month'] = df_trips['ride_month'].astype(CategoricalDtype(categories=month, ordered=False))

df_trips.insert(loc=8, column="ride_year", value= df_trips['started_at'].dt.year)

seasons_dict = {'Winter': ['December', 'January', 'February'],
                'Spring': ['March', 'April', 'May'],
                'Summer': ['June', 'July', 'August'],
                'Autumn': ['September', 'October', 'November']}
df_trips.insert(loc=9, column="ride_season", value= df_trips['ride_month'].map(
    {month: season for season, months in seasons_dict.items() for month in months}))

df_trips.head(4)
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  620BC6107255BF4C  electric_bike 2021-10-22 12:46:42 2021-10-22 12:49:50
# 1  4471C70731AB2E45  electric_bike 2021-10-21 09:12:37 2021-10-21 09:14:14
# 2  26CA69D43D15EE14  electric_bike 2021-10-16 16:28:39 2021-10-16 16:36:26
# 3  362947F0437E1514  electric_bike 2021-10-16 16:17:48 2021-10-16 16:19:03
#
#    ride_duration  ride_hour  ride_day ride_month  ride_year ride_season  \
# 0       3.133333         12    Friday    October       2021      Autumn
# 1       1.616667          9  Thursday    October       2021      Autumn
# 2       7.783333         16  Saturday    October       2021      Autumn
# 3       1.250000         16  Saturday    October       2021      Autumn
#
#          start_station_name start_station_id  start_lat  start_lot user_type
# 0  Kingsbury St & Kinzie St     KA1503000043  41.889186 -87.638495    member
# ...

# %%
df_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5712955 entries, 0 to 5712954
# Data columns (total 15 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       category
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   ride_duration       float64
#  5   ride_hour           int64
#  6   ride_day            category
#  7   ride_month          category
#  8   ride_year           int64
#  9   ride_season         object
#  10  start_station_name  object
#  11  start_station_id    object
#  12  start_lat           float64
#  13  start_lot           float64
#  14  user_type           category
# dtypes: category(4), datetime64[ns](2), float64(3), int64(2), object(4)
# memory usage: 501.2+ MB

# %% [markdown]
# > This dataset has been processed to make it **more clean and understandable** which will be helpful in the analysis stage to find **insights that can answer business tasks**.

# %% [markdown]
# # **Analyze**

# %% [markdown]
# > The **analyze stage** will be carried out by anal**yzing data** that has been organized to find **insights** that **answer business problems** and **tasks**. Of course, this **stage** will be **supported by visualizations** that can be understood and show the **key findings** of the **analysis**.
#
# > The essential skills for this phase are **analytical thinking, critical thinking, creative thinking, curiosity, and problem-solving**. **Being a Data Analyst is like being a Detective** where we have to find real evidence (**data**), understand patterns of criminal events (**analyzing data**), and look for relationships between facts in the court (**summarizing insights**) to find the culprit (**solutions for business problems**).

# %% [markdown]
# ## **Total Trips**
#
# > Users of the Cyclistic bike-sharing service are categorized into two types, which are **annual members and casual riders**. The total trips of each type of user on **October 2021 to September 2022** are shown below.

# %%
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: lime' if v and i != ('All', '') else '' for i,v in zip(s.index, is_max)]

# %%
df_pv1 = pd.pivot_table(df_trips,
                       index='user_type',
                       values='ride_id',
                       aggfunc=['count'],
                       margins=True,
                       margins_name='All')

total_count = df_pv1.loc['All', ('count', 'ride_id')]
df_pv1['% of count'] = df_pv1[('count', 'ride_id')].apply(lambda x: "{:.2%}".format(x / total_count))
df_pv1.style.background_gradient(cmap='YlGn', axis=0, subset=pd.IndexSlice[df_pv1.index[:-1], df_pv1.columns[:1]])
# Out:
# <style type="text/css">
# #T_e4465_row0_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_e4465_row1_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e4465" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4465_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_e4465_level0_col1" class="col_heading level0 col1" >% of count</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_e4465_level1_col0" class="col_heading level1 col0" >ride_id</th>
#       <th id="T_e4465_level1_col1" class="col_heading level1 col1" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >user_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4465_level0_row0" class="row_heading level0 row0" >casual</th>
# ...

# %% [markdown]
# > **Insight**
# * The **total trips** by both users during **October 2021** to **September 2022** are **5.71 million**.
# * Over the past 12 months, **annual members** recorded higher total trips compared to **casual riders**, accounting for **58.76% of total trips** or approximately **3.36 million trips**. Meanwhile, the total trips made by **casual riders** was **2.36 million trips (41.24% of total trips)**. It shows that **annual members** represent **the majority of bike trips** using **Cyclistic Bike-Share** during **October 2021** to **September 2022**.
#
# > Check out the pie chart visualization below for details.

# %%
fig_1 = df_trips.groupby('user_type', as_index=False).count()

fig_1_pie = px.pie(fig_1, names='user_type', values = 'ride_id', color='user_type',
                   hole = 0.45,
                   labels = {'ride_id': 'Number of Trips'},
                   title="Total Trips by Users<br>(Oct 2021 - Sep 2022)",
                   hover_name = 'user_type',
                   color_discrete_map={'member':'midnightblue','casual':'darkorange'})

fig_1_pie.update_traces(textposition='inside', textinfo='percent+label')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Median Trip Duration**
#
# > Once we know which users are taking the most trips, we can complement this with **insights** into each user's **trip duration** in **October 2021 to September 2022**.
#
# > Note that **the mean for the `ride_duration` variable is affected by outliers**, so **the median is a more accurate measurement for this analysis**.

# %%
df_pv2 = pd.pivot_table(df_trips,
                       index='user_type',
                       values='ride_duration',
                       aggfunc=['median'],
                       margins=True)
df_pv2.style.background_gradient(cmap='YlGn', axis=0, subset=pd.IndexSlice[df_pv2.index[:-1], df_pv2.columns[:1]])
# Out:
# <style type="text/css">
# #T_28829_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_28829_row1_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_28829" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28829_level0_col0" class="col_heading level0 col0" >median</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_28829_level1_col0" class="col_heading level1 col0" >ride_duration</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >user_type</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28829_level0_row0" class="row_heading level0 row0" >casual</th>
#       <td id="T_28829_row0_col0" class="data row0 col0" >13.716667</td>
#     </tr>
#     <tr>
#       <th id="T_28829_level0_row1" class="row_heading level0 row1" >member</th>
# ...

# %% [markdown]
# > **Insight**
# * Overall, **both** types of users spent about **10 minutes** using Cyclistic.
# * Although **annual members** make the **most trips** than **casual riders**, but **casual riders** spend more **time** than **annual members** in using Cyclistic, which is approximately **14 minutes** while **annual members** spend approximately **9 minutes**.
#
# > For more details, see the **horizontal bar chart** below showing the **median trip duration** of each user.

# %%
fig_2 = round(df_trips.groupby('user_type', as_index=False).median(),0)

px.bar(fig_2, y = 'user_type', x = 'ride_duration', range_x = [0,15],
        color = 'user_type', 
        height = 300,
        title="Median Trip Duration by Users<br>(Oct 2021 - Sep 2022)",
        text = 'ride_duration', 
        labels = {'ride_duration': 'Median Trip Duration (minutes)', 'user_type': 'User Type'},
        hover_name = 'user_type', hover_data = {'user_type': False, 'ride_duration': True}, 
        color_discrete_map = {'casual': '#FF934F', 'member': '#058ED9'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Total Monthly & Seasonal Trips**

# %% [markdown]
# > Having a total of **5.71 million trips** during **October 2021 to September 2022**, it is important to know the **busiest month and season** of Cyclistic trips to assist in determining **marketing strategies based** on **Cyclistic user behavior**.

# %% [markdown]
# ### **Seasonality**

# %%
df_pv3 = pd.pivot_table(df_trips,
              index = ['ride_season'],
              columns = ['user_type'],
              values = 'ride_id',
              aggfunc = ['count'],
              margins = True)
df_pv3.style.background_gradient(cmap='YlGn', axis=0, subset=pd.IndexSlice[df_pv3.index[:-1], df_pv3.columns[:3]])
# Out:
# <style type="text/css">
# #T_71cf9_row0_col0 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_71cf9_row0_col1 {
#   background-color: #1f8142;
#   color: #f1f1f1;
# }
# #T_71cf9_row0_col2 {
#   background-color: #3da559;
#   color: #f1f1f1;
# }
# #T_71cf9_row1_col0 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_71cf9_row1_col1 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_71cf9_row1_col2 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_71cf9_row2_col0, #T_71cf9_row2_col1, #T_71cf9_row2_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_71cf9_row3_col0, #T_71cf9_row3_col1, #T_71cf9_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_71cf9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71cf9_level0_col0" class="col_heading level0 col0" colspan="3">count</th>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# > **Insight**
# * From **October 2021 to September 2022**, **Cyclistic's total trips** were **highest** in the **summer** as well as for **each user (annual members and casual riders)**. According to [**Weather Spark**](https://id.weatherspark.com/s/14091/2/Cuaca-rata-rata-pada-Musim-gugur-di-Chicago-Illinois-Amerika-Serikat), **average summer temperatures** range from **20-28 degrees Celsius**, which is **warmer** than **other seasons** and Of course, the **lowest average temperature** occurs in **winter**, which is between **-6 to 1 degree Celsius**. That makes sense, as **warmer temperatures** are **suitable** for **cycling activities**, so the **busiest season** for **Cyclistic trips** is in the **summer**.
# * Overall, **annual members** recorded **more total Cyclistic trip**s in **all seasons**.

# %% [markdown]
# ### **Monthly**

# %%
df_pv3 = pd.pivot_table(df_trips,
              index = ['ride_year', 'ride_month','ride_season'],
              values = 'ride_id',
              aggfunc = ['count'],
              margins = False)
df_pv3 = df_pv3.loc[(df_pv3 != 0).any(axis=1)]
df_pv3['MoM (%)']=df_pv3.pct_change()*100
df_pv3.style.background_gradient(cmap='YlGn', axis=0)
# Out:
# <style type="text/css">
# #T_a6b1e_row0_col0 {
#   background-color: #268846;
#   color: #f1f1f1;
# }
# #T_a6b1e_row0_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a6b1e_row1_col0 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_a6b1e_row1_col1 {
#   background-color: #fafdcc;
#   color: #000000;
# }
# #T_a6b1e_row2_col0 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_a6b1e_row2_col1 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_a6b1e_row3_col0, #T_a6b1e_row3_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_a6b1e_row4_col0 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_a6b1e_row4_col1 {
#   background-color: #bae394;
#   color: #000000;
# }
# #T_a6b1e_row5_col0 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_a6b1e_row5_col1, #T_a6b1e_row9_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_a6b1e_row6_col0 {
#   background-color: #aedd8e;
#   color: #000000;
# ...

# %% [markdown]
# > **Insight**
# * **The most Cyclistic user trips** occurred in **July 2022** or **mid-summer**, recording approximately **8.05 hundred trips** which corresponds to the **seasonal insight** that **summer** has **warmer temperatures** and is **suitable** for **cycling activities**.
# * There is a **significant increase** in the number of **Cyclistic trips** by **141.74%** from **February (winter) to March (spring)** due to the **spring** season which has **warmer temperatures** than **winter**, so **Cyclistic activities increased more**.

# %%
df_pv4 = pd.pivot_table(df_trips,
              index = ['ride_year', 'ride_month','ride_season'],
              columns='user_type',
              values = 'ride_id',
              aggfunc = ['count'],
              margins = False)
df_pv4 = df_pv4.loc[(df_pv4 != 0).all(axis=1)]
df_pv4.style.background_gradient(cmap='YlGn', axis=0)
# Out:
# <style type="text/css">
# #T_5eee1_row0_col0 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_5eee1_row0_col1 {
#   background-color: #076d39;
#   color: #f1f1f1;
# }
# #T_5eee1_row1_col0 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_5eee1_row1_col1 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_5eee1_row2_col0 {
#   background-color: #f5fbb8;
#   color: #000000;
# }
# #T_5eee1_row2_col1 {
#   background-color: #d2eda0;
#   color: #000000;
# }
# #T_5eee1_row3_col0, #T_5eee1_row3_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_5eee1_row4_col0 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_5eee1_row4_col1 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_5eee1_row5_col0 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_5eee1_row5_col1 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_5eee1_row6_col0 {
#   background-color: #cfec9e;
#   color: #000000;
# }
# ...

# %% [markdown]
# > **Insight**
# * **Annual members** make **more trips** than **casual riders** in **every month**.
# * **The trend of total monthly trips** of **both user types** is **quite similar**. The trend starts with a **decline in November through January (winter)** then began to **increase** in **February (winter)**, but the **increase** was **quite large** in **March (spring)** and **peaks in July (summer) for casual users** while for **annual members it peaks in August (summer)** after which it **continues to decline again**. **That insight** corresponds to the **seasonal insight**.

# %% [markdown]
# > Below is a bar chart visualization for **the total monthly trips** during **October 2021 to September 2022** by **both users**.

# %%
fig_3 = df_trips.groupby(['ride_year', 'ride_month', 'user_type'], as_index=False).count()
fig_3 = fig_3[fig_3['ride_id'] != 0]

fig_3_bar = px.bar(fig_3, x = 'ride_month', y = 'ride_id', text='ride_id', 
                   range_y = [0,500000],
                   color = 'user_type', 
                   barmode='group',
                   title="Total Monthly Trips by Users<br>(Oct 2021 - Sep 2022)",
                   labels = {'ride_id': 'Total Trips', 'ride_month': 'Months', 'ride_year': 'Year', 'user_type': 'User Type'},
                   hover_name = 'user_type', hover_data = {'user_type': False, 'ride_month': True, 'ride_year': True, 'ride_id': True}, 
                   color_discrete_map = {'casual': 'darkorange', 'member': 'midnightblue'})

fig_3_bar.add_vrect(x0=1.5, x1=4.5, 
                    annotation_text="Winter months", annotation_position="top left",  
                    annotation_font_size=12,
                    annotation_font_color="darkgreen",
                    fillcolor="Green", 
                    opacity=0.15, line_width=0)

fig_3_bar.add_vrect(x0=7.5, x1=10.5, 
                    annotation_text="Summer months", annotation_position="top left",  
                    annotation_font_size=12,
                    annotation_font_color="maroon",
                    fillcolor="firebrick", opacity=0.15, line_width=0)

fig_3_bar.update_traces(texttemplate='%{text:.2s}', 
                        textposition='outside')

fig_3_bar.update_layout(autosize=False, 
                        width=1150, height=600)

fig_3_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Median Monthly & Seasonal Trip Duration**
# > Understanding the **monthly** and **seasonality** of **trip duration** of both types of Cylistic users in **October 2021 to September 2022** is also important to find **insights** that can improve further **analysis**.

# %% [markdown]
# ### **Seasonality**

# %%
df_pv5 = pd.pivot_table(df_trips,
              index = ['ride_season'],
              columns= 'user_type',
              values = 'ride_duration',
              aggfunc = ['median'],
              margins = False)
df_pv5 = df_pv5.loc[(df_pv5 != 0).any(axis=1)]
df_pv5.style.background_gradient(cmap='YlGn', axis=0)
# Out:
# <style type="text/css">
# #T_a245d_row0_col0 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_a245d_row0_col1, #T_a245d_row1_col1 {
#   background-color: #92d183;
#   color: #000000;
# }
# #T_a245d_row1_col0, #T_a245d_row2_col1 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_a245d_row2_col0 {
#   background-color: #1d7f41;
#   color: #f1f1f1;
# }
# #T_a245d_row3_col0, #T_a245d_row3_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_a245d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a245d_level0_col0" class="col_heading level0 col0" colspan="2">median</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >user_type</th>
#       <th id="T_a245d_level1_col0" class="col_heading level1 col0" >casual</th>
#       <th id="T_a245d_level1_col1" class="col_heading level1 col1" >member</th>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# > **Insight**
# * **Casual riders** consistently spend a **longer time** than **annual members** in **each season**.
# * **Annual members** spend more time on trips in the **summer** and **casual riders** in the **spring**. **Spring** in **Chicago** has an **average high temperature** of **17 degrees Celsius** which is **lower** than the **average summer high temperature** of **28 degrees Celsius**. **The mild temperatures and springtime atmosphere** make **casual riders** feel comfortable on their bikes, so they spend more time in **spring**.
# * **Both** spent **less time** on Cyclistic trips in **winter**. **Winter** in **Chicago** has an **average high temperature** of around **1 degree Celsius** which is certainly **not comfortable** for users to take Cyclistic trips.
#
# *Temperature information in Chicago based on [Weather Spark](https://id.weatherspark.com/y/14091/Cuaca-Rata-rata-pada-bulan-in-Chicago-Illinois-Amerika-Serikat-Sepanjang-Tahun)*

# %% [markdown]
# ### **Monthly**

# %%
df_pv6 = pd.pivot_table(df_trips,
              index = ['ride_year', 'ride_month','ride_season'],
              columns='user_type',
              values = 'ride_duration',
              aggfunc = ['median'],
              margins = False)
df_pv6 = df_pv6.loc[(df_pv6 != 0).any(axis=1)]
df_pv6.style.background_gradient(cmap='YlGn', axis=0)
# Out:
# <style type="text/css">
# #T_b890d_row0_col0 {
#   background-color: #349a52;
#   color: #f1f1f1;
# }
# #T_b890d_row0_col1 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_b890d_row1_col0 {
#   background-color: #e3f4aa;
#   color: #000000;
# }
# #T_b890d_row1_col1 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_b890d_row2_col0, #T_b890d_row4_col0 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_b890d_row2_col1 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_b890d_row3_col0, #T_b890d_row3_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_b890d_row4_col1 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_b890d_row5_col0 {
#   background-color: #177b3f;
#   color: #f1f1f1;
# }
# #T_b890d_row5_col1 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# #T_b890d_row6_col0 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }
# #T_b890d_row6_col1 {
#   background-color: #edf8b1;
#   color: #000000;
# ...

# %% [markdown]
# > **Insight**
# * Like previous insights, **casual riders** spend **more time** on Cyclistic trips in **spring**, precisely in **May 2022** with an median trip duration of about **16 minutes**.
# * **Annual members** spent **more time** on Cyclistic trips in **June 2022 (summer)** with a median trip duration of about **10 minutes**. **June 2022** is a hot summer in Chicago with **average high temperatures** reaching **25 degrees Celsius** which is **lower** than **other months (July and August 2022)** in **summer**. So it can be considered **cooler** than **other months** in the **summer** and **suitable** for **prolonged cycling activities**.
# * Of course, **both users** spent **less time** in **winter** and precisely in **January 2022**, where the **lowest point** of the **highest average temperature** in **winter** occurred in **January 2022** at around **0 degrees Celsius**. This temperature is **not suitable** for **prolonged cycling**.
#
# *Temperature information in Chicago based on [Weather Spark](https://id.weatherspark.com/y/14091/Cuaca-Rata-rata-pada-bulan-in-Chicago-Illinois-Amerika-Serikat-Sepanjang-Tahun)*

# %% [markdown]
# > Here's a **bar chart visualization** showing the **median monthly trip duration** by both types of users.

# %%
fig_4 = round(df_trips.groupby(['ride_year', 'ride_month', 'user_type'], as_index=False).median(),2).dropna()

fig_4_bar = px.bar(fig_4, x = 'ride_month', y = 'ride_duration', 
                   range_y = [0,18],
                   color = 'user_type',
                   barmode ='group',
                   title="Median Monthly Trip Duration by Users<br>(Oct 2021 - Sep 2022)",
                   text = 'ride_duration', 
                   labels = {'ride_duration': 'Median Trip Duration (minutes)', 'user_type': 'User Type', 'ride_month': 'Months'},
                   hover_name = 'user_type', hover_data = {'user_type': False, 'ride_duration': True}, 
                   color_discrete_map = {'casual': 'darkorange', 'member': 'midnightblue'})

fig_4_bar.add_vrect(x0=1.5, x1=4.5, 
                    annotation_text="Winter months", annotation_position="top left",  
                    annotation_font_size=12,
                    annotation_font_color="darkgreen",
                    fillcolor="Green",
                    opacity=0.15, line_width=0)

fig_4_bar.add_vrect(x0=4.5, x1=7.5, 
                    annotation_text="Spring months", annotation_position="top left",  
                    annotation_font_size=12,
                    annotation_font_color="darkslateblue",
                    fillcolor="navy", opacity=0.15, line_width=0)

fig_4_bar.add_vrect(x0=7.5, x1=10.5, 
                    annotation_text="Summer months", annotation_position="top left",  
                    annotation_font_size=12,
                    annotation_font_color="maroon",
                    fillcolor="firebrick", opacity=0.15, line_width=0)

fig_4_bar.update_traces(texttemplate='%{text:.4s}', 
                        textposition='outside')

fig_4_bar.update_layout(autosize=False, 
                        width=1150, height=600)
fig_4_bar.update_yaxes(dtick=1)

fig_4_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Total Daily Trips in a Week**

# %% [markdown]
# > In addition, knowing the **busiest day of the week** for **Cyclistic trips** during **October 2021 to September 2022** is an important **insight** that can be a **recommendation** in determining **effective days** for **marketing strategies**.

# %%
df_pv7 = pd.pivot_table(df_trips,
              index = 'ride_day',
              columns= 'user_type',
              values = 'ride_id',
              aggfunc = ['count'],
              margins = True)
df_pv7.style.background_gradient(cmap='YlGn', axis=0, subset=pd.IndexSlice[df_pv7.index[:-1], df_pv7.columns[:3]])
# Out:
# <style type="text/css">
# #T_48e70_row0_col0 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_48e70_row0_col1 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_48e70_row0_col2, #T_48e70_row1_col0, #T_48e70_row6_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_48e70_row1_col1, #T_48e70_row5_col0, #T_48e70_row5_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_48e70_row1_col2 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_48e70_row2_col0 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_48e70_row2_col1 {
#   background-color: #004a2b;
#   color: #f1f1f1;
# }
# #T_48e70_row2_col2 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_48e70_row3_col0 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_48e70_row3_col1 {
#   background-color: #005a31;
#   color: #f1f1f1;
# }
# #T_48e70_row3_col2 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_48e70_row4_col0 {
# ...

# %% [markdown]
# > **Insight**
# * **Busiest day** of the week for **all Cyclistic users** is **Saturday**.
# * **Annual members** trip more during **weekdays** with the busiest day on **Tuesday**, while casual riders trip more on **weekends** with the busiest day on **Saturdays**. The insights indicate that the majority of **casual riders** use Cyclistic for **leisure** and most **annual members** use Cyclistic for **work or school**. However, it is possible that **annual members** also use Cyclistic for **leisure** where their total trips on **weekends** are also **quite large**. That can be **confirmed** if there is **personal user data** such as **the user's occupation** to better understand the user's purpose in using Cyclistic.
#
# > **Bar chart visualization** showing the **total daily trips in a week** by each Cyclistic user during **October 2021 to September 2022** can be seen below.

# %%
fig_5 = df_trips.groupby(['ride_day', 'user_type'], as_index=False).count()

fig_5_bar = px.bar(fig_5, x = 'ride_day', y = 'ride_id', text='ride_id', range_y = [0,600000],
                     color = 'user_type', 
                     barmode='group',
                     title="Total Daily Trips in a Week by Users<br>(Oct 2021 - Sep 2022)",
                     labels = {'ride_id': 'Total Trips', 'ride_day': 'Days', 'user_type': 'User Type'},
                     hover_name = 'user_type', hover_data = {'user_type': False, 'ride_month': False, 'ride_id': True}, 
                     color_discrete_map = {'casual': 'darkorange', 'member': 'midnightblue'})

fig_5_bar.add_vrect(x0=4.5, x1=6.5, 
              annotation_text="Weekend", annotation_position="top left",  
              annotation_font_size=14,
              annotation_font_color="darkgreen",
              fillcolor="green", opacity=0.15, line_width=1)

fig_5_bar.add_vrect(x0=-0.5, x1=4.5, 
              annotation_text="Weekday", annotation_position="top left",  
              annotation_font_size=14,
              annotation_font_color="maroon",
              fillcolor="firebrick", opacity=0.15, line_width=1)

fig_5_bar.update_traces(texttemplate='%{text:.4s}', textposition='inside')

fig_5_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Median Daily Trip Duration in a Week**

# %% [markdown]
# > How **annual members (Cyclistic members)** and **casual riders** use Cyclistic bikes differently can be seen in more detail by **analyzing** their **daily trip duration in a week** during **October 2021 to September 2022**.

# %%
df_pv8 = pd.pivot_table(df_trips,
              index = 'ride_day',
              columns= 'user_type',
              values = 'ride_duration',
              aggfunc = ['median'],
              margins = False)
df_pv8.style.background_gradient(cmap='YlGn', axis=0)
# Out:
# <style type="text/css">
# #T_6d67d_row0_col0 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_6d67d_row0_col1, #T_6d67d_row1_col1, #T_6d67d_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_6d67d_row1_col0 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_6d67d_row2_col1 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# #T_6d67d_row3_col0 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_6d67d_row3_col1 {
#   background-color: #f9fdc2;
#   color: #000000;
# }
# #T_6d67d_row4_col0 {
#   background-color: #d5eea1;
#   color: #000000;
# }
# #T_6d67d_row4_col1 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_6d67d_row5_col0 {
#   background-color: #00502d;
#   color: #f1f1f1;
# }
# #T_6d67d_row5_col1, #T_6d67d_row6_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_6d67d_row6_col1 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6d67d" class="dataframe">
# ...

# %% [markdown]
# > **Insight**
# * **Saturdays** are favored by **annual members** for longer rides while **casual riders** spend more time on **Sundays**. It can be inferred that these **two types of users** spend more time using Cyclistic on **weekends**, presumably to **leisure**.
# * The trip duration of **casual riders** is more variable compared to **annual members** where as **annual members** trip duration tends to be **consistent** during **weekdays**. The duration of **annual members'** trips is also **shorter** during **weekdays** than **casual riders**. It is possible that the trip duration of **annual members** is **shorter** because they **live near work or school** and choose to commute to these places by **Cyclistic bike-sharing system**. **Casual riders** may have **longer** trip durations because they use it for **leisure or sightseeing**.
# * If there is **personal user data** such as **occupation or residential address**, it will be possible to determine exactly what causes **casual riders** and **annual members** to have **different trip durations**. Regardless, the increase in **weekend trip duration** for **both users** is **not clearly known** due to **deficiencies** in the dataset used.

# %%
fig_6 = round(df_trips.groupby(['ride_day', 'user_type'], as_index=False).median(),2)

fig_6_bar = px.bar(fig_6, x = 'ride_day', y = 'ride_duration', range_y = [0,18],
                   color = 'user_type',
                   barmode ='group',
                   title="Median Daily Trip Duration in a Week by Users<br>(Oct 2021 - Sep 2022)",
                   text = 'ride_duration', 
                   labels = {'ride_duration': 'Median Trip Duration (minutes)', 'user_type': 'User Type', 'ride_day': 'Days'},
                   hover_name = 'user_type', hover_data = {'user_type': False, 'ride_duration': True}, 
                   color_discrete_map = {'casual': 'darkorange', 'member': 'midnightblue'})

fig_6_bar.add_vrect(x0=4.5, x1=6.5, 
              annotation_text="Weekend", annotation_position="top left",  
              annotation_font_size=14,
              annotation_font_color="darkgreen",
              fillcolor="green", opacity=0.15, line_width=1)

fig_6_bar.add_vrect(x0=-0.5, x1=4.5, 
              annotation_text="Weekday", annotation_position="top left",  
              annotation_font_size=14,
              annotation_font_color="maroon",
              fillcolor="firebrick", opacity=0.15, line_width=1)

fig_6_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Total Hourly Trips**

# %% [markdown]
# > Taking a closer look at what time of day the **most bicycle trips start** will provide more detailed **insights** into the differences between **annual members** and **casual riders** using **Cyclistic** by **hour**, allowing us to identify the **busiest time** users start their trips. These **insights** will help determine the **busiest time** for Cyclistic users. This will also help in determining **marketing strategies** based on the **busiest hours** of bike trips.

# %%
df_pv9 = pd.pivot_table(df_trips,
              index=['ride_hour'],
              columns='user_type',
              values='ride_id',
              aggfunc=['count'],
              margins=False)

df_pv9['% Difference']  = (((df_pv9['count']['casual'] - df_pv9['count']['member']).abs())/
                           (df_pv9['count']['casual'] + df_pv9['count']['member']))*100
df_pv9.style.background_gradient(cmap='YlGn', axis=0)
# Out:
# <style type="text/css">
# #T_7838b_row0_col0 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_7838b_row0_col1 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_7838b_row0_col2 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_7838b_row1_col0 {
#   background-color: #f8fcc0;
#   color: #000000;
# }
# #T_7838b_row1_col1 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_7838b_row1_col2 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_7838b_row2_col0 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_7838b_row2_col1 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_7838b_row2_col2, #T_7838b_row10_col1 {
#   background-color: #abdc8d;
#   color: #000000;
# }
# #T_7838b_row3_col0 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_7838b_row3_col1, #T_7838b_row4_col0, #T_7838b_row4_col1, #T_7838b_row22_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_7838b_row3_col2 {
# ...

# %% [markdown]
# > **Insight**
# * **5 pm** is the **busiest time** for **both users** to start their trip with Cyclistic. Perhaps they are **returning from work** or **leisure** using Cyclistic.
# * During **4 am to 9 pm**, **more trips** were taken by **annual members** than **casual riders**. Then from **10 pm to 3 am**, it was the **casual riders** who made **more trips** which could have been them **leisure** using **Cyclistic** in the **Chicago** city **throughout the night**.
# * The **difference** in **total trips** between **annual members** and **casual riders** is quite **large** during **5 am to 9 am** where the **total trips** by **annual members** are **larger**, indicating that many **annual members** are **going to work or school** at that time. However, this needs to be **validated** with **users' personal data** such as their **occupation**.
# * The **total trips** for **each user** started to **increase** at **5 am**, indicating that **both users** started their **daily activities with Cyclistic** at that hour.
#
#
#
#
# > For more details, the **line graph** below shows the totals of trip starts by user on an **hourly** basis.

# %%
fig_7 = df_trips.groupby(['ride_hour', 'user_type'], as_index=False).count()

fig_7_line = px.line(fig_7, x = 'ride_hour', y = 'ride_id', range_x = [0,23], range_y = [0,400000],
                 color = 'user_type',
                 line_shape = 'spline',
                 markers=True,
                 title="Total Hourly Trips by User<br>(Oct 2021 - Sep 2022)",
                 labels = {'ride_id': 'Total Trips', 'ride_hour': 'Hours', 'user_type': 'User Type'},
                 hover_name = 'user_type', hover_data = {'user_type': False, 'ride_month': False, 'ride_id': True},
                 color_discrete_map = {'casual': 'darkorange', 'member': 'midnightblue'})

fig_7_line.add_annotation(x=5, y=380000, text=f'Total trips for each user<br>started to increase',
                          xanchor='right',
                          showarrow=False,
                          ax=0, ay=0, 
                          font=dict(size=12, color="purple"), 
                          align="right")

fig_7_line.add_annotation(x=17, y=390000, text=f'Busiest time for each user',
                          xanchor='left',
                          showarrow=False,
                          ax=0, ay=0, 
                          font=dict(size=12, color="firebrick"), 
                          align="left")

fig_7_line.update_layout(shapes=
                         [dict(type= 'line', 
                               yref= 'paper', y0= 0, y1= 1, 
                               xref= 'x', x0='17', x1='17',
                               line=dict(color="maroon",width=3,dash="dot")),
                          dict(type= 'line',
                               yref= 'paper', y0= 0, y1= 1,
                               xref= 'x', x0='5', x1='5',
                               line=dict(color="MediumPurple",width=3,dash="dot"))])

fig_7_line.add_vrect(x0=5, x1=9, 
              annotation_text="Large difference<br>in total trips<br>between users", annotation_position="top",  
              annotation_font_size=12,
              annotation_font_color="darkgreen",
              fillcolor="green", opacity=0.15, line_width=1)


fig_7_line.update_xaxes(dtick=1)
fig_7_line.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **User Trip Start Station**

# %% [markdown]
# > The **starting station** of the **user's trip** can be a **recommendation** in choosing the **location** of the **marketing campaign** because there is **no user's residential address data** due to **personal data privacy**. Therefore, it is important to know which is the **most preferred station** by each user to **pick up the bike** and **start their trip**.
#
# > As mentioned earlier, the **`start_station_name`** variable has **missing values** of about **15%** of the total rows/records and this will be **discussed** with the **marketing director** and the **marketing analytics team**.

# %% [markdown]
# ### **Annual Members**

# %%
station_member = df_trips[df_trips['user_type'] == 'member']

df_pv10 = pd.pivot_table(station_member,
               index = ['start_station_name'],
               values = ['ride_id'],
               aggfunc = ['count'])

df_pv10.sort_values(('count', 'ride_id'), ascending=False).head(10).style.background_gradient(cmap='YlGn', axis=0)
# Out:
# <style type="text/css">
# #T_fc06c_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_fc06c_row1_col0 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_fc06c_row2_col0 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_fc06c_row3_col0, #T_fc06c_row4_col0, #T_fc06c_row5_col0 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_fc06c_row6_col0 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_fc06c_row7_col0 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_fc06c_row8_col0 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_fc06c_row9_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_fc06c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc06c_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
# ...

# %% [markdown]
# > **Insight**
# * **Kingsbury St & Kinzie St stations** are the **busiest stations** for **annual members** to **pick up their bikes** and **start their trips**.

# %% [markdown]
# ### **Casual Riders**

# %%
station_casual = df_trips[df_trips['user_type'] == 'casual']

df_pv11 = pd.pivot_table(station_casual,
               index = ['start_station_name'],
               values = ['ride_id'],
               aggfunc = ['count'])

df_pv11.sort_values(('count', 'ride_id'), ascending=False).head(10).style.background_gradient(cmap='YlGn', axis=0)
# Out:
# <style type="text/css">
# #T_d6d63_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_d6d63_row1_col0 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_d6d63_row2_col0 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_d6d63_row3_col0 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_d6d63_row4_col0 {
#   background-color: #e2f4aa;
#   color: #000000;
# }
# #T_d6d63_row5_col0 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_d6d63_row6_col0 {
#   background-color: #f8fdc1;
#   color: #000000;
# }
# #T_d6d63_row7_col0 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_d6d63_row8_col0, #T_d6d63_row9_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_d6d63" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6d63_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# > **Insight**
# * **Streeter Dr & Grand Ave station** is the **busiest station** to **pick up a bike** and **start a trip** by **casual riders**.

# %% [markdown]
# > Below is a **bar graph** showing the **10 busiest stations** used to **pick up bikes** and **start trips** by **casual riders** and **annual members**.

# %%
# Calculate the number of ride_id for each start_station_name and user_type
station_start_count = df_trips.groupby(['start_station_name', 'user_type'])['ride_id'].count().reset_index()

# Filter the data for user_type = 'casual' and 'member'
station_casual = station_start_count[station_start_count['user_type'] == 'casual']
station_member = station_start_count[station_start_count['user_type'] == 'member']

# Sort the data in descending order of ride_id, and take the top 10 for each user type
station_casual = station_casual.sort_values('ride_id', ascending=False).head(10)
station_member = station_member.sort_values('ride_id', ascending=False).head(10)

# Add a new column to indicate whether a bar is highlighted
station_casual['highlight'] = station_casual['start_station_name'] == station_casual.iloc[0]['start_station_name']
station_member['highlight'] = station_member['start_station_name'] == station_member.iloc[0]['start_station_name']

# Create a subplot with two rows and one column
fig_7_bar = make_subplots(rows=2, cols=1, shared_xaxes=False, vertical_spacing=0.15, subplot_titles=['Casual Riders', 'Annual Member'])

# Add the top start stations for casual riders to the subplot
fig_7_bar.add_trace(go.Bar(
    y=station_casual['start_station_name'],
    x=station_casual['ride_id'],
    orientation='h',
    text=station_casual['ride_id'],
    textposition='auto',
    hovertemplate='%{y} - %{x}<extra></extra>',
    marker=dict(color=station_casual['highlight'].map({True: 'darkorange', False: 'grey'})),
    showlegend=False
), row=1, col=1)

# Add the top start stations for annual members to the subplot
fig_7_bar.add_trace(go.Bar(
    y=station_member['start_station_name'],
    x=station_member['ride_id'],
    orientation='h',
    text=station_member['ride_id'],
    textposition='auto',
    hovertemplate='%{y} - %{x}<extra></extra>',
    marker=dict(color=station_member['highlight'].map({True: 'midnightblue', False: 'grey'})),
    showlegend=False
), row=2, col=1)

# Update xaxis properties
fig_7_bar.update_xaxes(title_text="Total Start Trip", row=1, col=1)
fig_7_bar.update_xaxes(title_text="Total Start Trip", row=2, col=1)

fig_7_bar.update_yaxes(autorange='reversed', row=1, col=1)
fig_7_bar.update_yaxes(autorange='reversed', row=2, col=1)

# Update the layout of the subplot
fig_7_bar.update_layout(
    height=800,
    title={
        'text': 'Top 10 Start Stations by ',
        'y': 0.95,
        'x': 0.2,
        'xanchor': 'center',
        'yanchor': 'top'})

# Show the plot
fig_7_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **Type of Bikes Used by User**

# %% [markdown]
# > According to dataset, **Cyclistic Bike-Share** has different **types of bikes** that can be used, which are **classic bikes, docked bikes, and electric bikes**. Therefore, it is necessary to **analyze** the **types of bikes** that are **most frequently used** by **both users** from **October 2021 to September 2022**.
#
#
# ---
#
# > *Notes: The **dataset** used does **not contain information** on the use of **reclining bikes, cargo bikes and hand tricycles**.*

# %%
df_pv12 = pd.pivot_table(df_trips,
               index = ['rideable_type'],
               columns= 'user_type',
               values = ['ride_id'],
               aggfunc = ['count'],
               margins = True)

df_pv12.style.background_gradient(cmap='YlGn', axis=0, subset=pd.IndexSlice[df_pv12.index[:-1], df_pv12.columns[:3]])
# Out:
# <style type="text/css">
# #T_b28bd_row0_col0 {
#   background-color: #2e924c;
#   color: #f1f1f1;
# }
# #T_b28bd_row0_col1, #T_b28bd_row2_col0, #T_b28bd_row2_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_b28bd_row0_col2 {
#   background-color: #00512e;
#   color: #f1f1f1;
# }
# #T_b28bd_row1_col0, #T_b28bd_row1_col1, #T_b28bd_row1_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_b28bd_row2_col1 {
#   background-color: #006335;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b28bd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b28bd_level0_col0" class="col_heading level0 col0" colspan="3">count</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_b28bd_level1_col0" class="col_heading level1 col0" colspan="3">ride_id</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >user_type</th>
# ...

# %% [markdown]
# > **Insight**
# * **Electric bikes** are most commonly used by all users for trips.
# * **Casual riders** prefer to use **electric bike** while **annual members** prefer to use **classic bike** for their trips.
# * **Only casual riders** use **docked bikes** for trips and that needs to be discussed.
#
# > Below is a **bar chart** showing the **frequency** of **bike types used** by **user type** during **October 2021 to September 2022**.

# %%
fig_8 = df_trips.groupby(['user_type','rideable_type'], as_index=False).count()

fig_8_bar = px.bar(fig_8, x = 'user_type', y = 'ride_id', range_y = [0,2000000],
                   color = 'rideable_type', barmode= 'group',
                   text = 'ride_id', 
                   title="Type of Bike Used by Users<br>(Oct 2021 - Sep 2022)",
                   labels = {'ride_id': 'Total Trips', 'user_type': 'User Type', 'rideable_type' : 'Bike Type'},
                   hover_name = 'user_type', hover_data = {'user_type': False},
                   color_discrete_map = {'classic_bike': 'navy', 'docked_bike': 'maroon', 'electric_bike': 'seagreen'})

fig_8_bar.update_traces(texttemplate='%{text:.2s}', textposition='outside')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# > Next, we need to know the **type of bike** that is **used** the **longest** by **each user**.

# %%
df_pv13 = pd.pivot_table(df_trips,
                         index = ['user_type', 'rideable_type'],
                         values = ['ride_duration'],
                         aggfunc = ['max','mean','median'])

df_pv13.style.background_gradient(cmap='YlGn', axis=0)
# Out:
# <style type="text/css">
# #T_e7e7a_row0_col0, #T_e7e7a_row3_col0 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_e7e7a_row0_col1 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_e7e7a_row0_col2 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_e7e7a_row1_col0, #T_e7e7a_row1_col1, #T_e7e7a_row1_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_e7e7a_row2_col0, #T_e7e7a_row4_col0, #T_e7e7a_row4_col1, #T_e7e7a_row4_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_e7e7a_row2_col1, #T_e7e7a_row3_col2 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_e7e7a_row2_col2 {
#   background-color: #eff9b3;
#   color: #000000;
# }
# #T_e7e7a_row3_col1 {
#   background-color: #feffde;
#   color: #000000;
# }
# </style>
# <table id="T_e7e7a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# > **Insight**
# * **Docked bikes** are used the **longest**, which is about **40,705 minutes** or **28 days**. This shows that the **outliers** we found are **mostly caused** by the **docked bike** usage data.
# * Although **casual riders** make more trips on **electric bikes**, but they **spend more time** on **classic bikes**. However, this is **related** to the **speed** that can be **achieved** by **each type of bike** where **electric bikes** can help **users** to go **faster** with the help of electric components if the user is tired of pedaling.
#
# > Based on the **insights** gained, it should be checked if it is **correct** that the **outliers** found are **mostly** from **docked bikes**. **Checking** for **outliers** can be done with a **box plot**.

# %%
sns.boxplot(data = df_trips, x ='rideable_type', y = 'ride_duration', order = ['classic_bike', 'docked_bike', 'electric_bike'])
plt.show()

# %% [markdown]
# > **Insight**
# * It is now clear from the **box plot** above that the **docked bikes** are the **cause** of the **outliers** affecting the a**verage `ride_duration` variable** from the previous analysis. This is something that should be **discussed** further with the **director and marketing team**.

# %% [markdown]
# ## **A Summary of The Analysis**

# %% [markdown]
# > Following is a **summary analysis** of **historical dataset of bike trips by Cyclistic users** during **October 2021 - September 2021** to **identify** how **annual members** and **casual riders** use Cyclistic differently:
# 1.   **Annual members** recorded **more trips using Cyclistic** than **casual riders**. However, it is the **casual riders** who **spend more time using Cyclistic** than the **annual members**.
# 2. **The busiest season** for **both types of users** to trip using Cyclistic is in **summer**. **Annual members spend more time cycling** in the **summer** and **casual riders** in the **spring**.
# 3. **The busiest month** for Cyclistic usage by **annual members** was in **August 2022** while for **casual riders** it was in **July 2022**. But, **annual members spent more time on bike trips** in **June 2022** while **casual riders** in **May 2022**.
# 4. **Saturday (weekend)** is the **busiest day** of Cyclistic usage by **casual riders**, while **Tuesday (weekday)** is the **busiest day** for **annual members**. **Annual members** made **more trips** during **weekdays** while for **casual riders** during **weekends**. Overall, the **trip duration** by **casual riders** is **longer** than **annual members** and **casual riders** use Cyclistic **longer** on **weekends** which **indicates** that **they** use Cyclistic for **leisure**. In addition, the **consistent trip duration** of **annual members** during **weekdays** also **indicates** that **they** use Cyclistic for **work or school**.
# 5. **5 pm** is the **busiest time** for **both users** to **start a trip using Cyclistic**, which may be them **returning from work or leisure** using Cyclistic. Activity using Cyclistic by **casual riders** and **annual members** starts to **increase** at **5 am** which suggests that **both users** start **their daily activities** with Cyclistic at that time. **Annual members** were **recorded** as **using Cyclistic more** from **4 am to 9 pm**, while **10 am to 3 am** were **more trips** made by **casual riders** and perhaps **they** used Cyclistic to **leisure** during night hours in Chicago. The **large difference** in **total trips** between **annual members** and **casual riders** at **5 am to 9 am** with **more trips** made by **annual members** suggests that **annual members** are **commuting to work or school** at these hours using Cyclistic. However, this needs to be validated with **users' personal data** such as **occupation**.
# 6. **Streeter Dr & Grand Ave** are the **busiest stations** for **casual riders** to **pick up** Cyclistic bikes while **annual members** prefer **Kingsbury St & Kinzie St** stations to **pick up** Cyclistic bikes.
# 7. **Casual riders** prefer to use **electric bike** while **annual members** prefer to use **classic bike** for their trips. **Docked bike are only used by casual riders** and this needs to be discussed during team meetings.

# %% [markdown]
# > After conducting **analysis** with the **support of visualization** and obtaining **key findings**, it is clear how **casual riders** and **annual members** **use Cyclistic bikes differently**:
# 1. **Casual riders** tend to use **Cyclistic** during **summer** (especially in **August 2022**) and on **weekends**, also they have **longer trip duration**. These factors suggest that **casual riders** use **Cyclistic** for **leisure**.
# 2. **Annual members** tend to use **Cyclistic's bike-sharing system** during **summer** (especially in **July 2022**) and on **weekdays**, also **their trip duration** is more **consistent** during **weekdays**. However, **their trip duration** is **shorter** than **casual riders**. Based on these factors, it shows that **they** use **Cyclistic** for **commuting to work/school** or **running errands** on **weekends**.

# %% [markdown]
# # **Share**

# %% [markdown]
# > At this stage, the **results** of the **analysis** and **deliverables** will be shared through a **presentation** that is more concise and can be accessed at [**Google Data Analytics Capstone: Cyclistic Bike-Share**](https://docs.google.com/presentation/d/1xUDzvFXJKoce95YgrU8Qb8VUO5_1fhbt5wmR5OUI9NU/edit?usp=sharing)

# %% [markdown]
# # **Act**

# %% [markdown]
# > At this stage, **recommendations** will be given that can be given to help **business goals or business decision-making** based on the tasks assigned to a data analyst, which is to **analyze the dataset**.

# %% [markdown]
# > **Top 3 recommendations for converting casual riders to annual members based on the analysis of historical bike trip datasets to identify how annual members and casual riders use Cyclistic bikes differently in October 2021 - September 2022:**
#
# 1.  **Promotional campaigns for annual membership sign-ups are only during the summer period or July.** Promotions may include discounts or special rates for annual membership sign-ups or additional benefits specific to being an annual member such as priority access to a desired bike or free Cyclistic Bike Share exclusive merchandise such as bags. The promotion aims to attract and encourage casual riders to become annual members **based on the insight that casual riders make more trips during summer and July**. Free exclusive Cyclistic Bike Share merchandise such as bags can be a cost-effective marketing medium while increasing Cyclistic's brand awareness.
#
# 2. **Third-party service discounts for annual members**. Cyclistic Bike Share can negotiate discounts with third-party services such as entertainment venues or local restaurants. **This discount can be campaigned on weekends or 5 pm as casual riders are more likely to trip with Cyclistic on those days and times**. **The campaign can be done through advertisements at the 10 stations most used by casual riders to pick up bikes** or by sending promotional emails to them for cost savings. This discount can encourage casual riders to sign up for Cyclistic membership and make annual members more satisfied with Cyclistic's services, potentially retaining them.
#
# 3. **Developing a reward point system for annual members**. Points can be awarded to annual members who frequently use Cyclistic and spend a lot of time cycling, share stories about their cycling trips using Cyclistic or the benefits of being an annual Cyclistic member on social media, and successfully invite others to register for Cyclistic membership through a referral marketing concept. **This system can be implemented through the Cyclistic mobile application to make it easier to track the points collected by annual members and can be redeemed directly for membership extension discounts or prizes such as exclusive Cyclistic Bike Share merchandise**. This can be a strong incentive for annual members to continue using Cyclistic and inviting others to join Cyclistic membership. Additionally, asking annual members to create social media content about their Cyclistic activities will reduce marketing costs and increase brand awareness on social media.
